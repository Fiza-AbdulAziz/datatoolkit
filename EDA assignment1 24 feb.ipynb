# %% [raw]
# #eda assignment 1
# #Downloads/heart_failure_clinical_records_dataset.csv
# Death Event:
# Indicates whether the patient died during the follow-up period (binary: 0 for no, 1 for yes).
# 1.What is the distribution of age among heart failure patients in the dataset?
# 2. How does the death rate vary with age?
# 3. What is the percentage of male and female patients in the dataset?

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")
plt.style.use("fivethirtyeight")
# %matplotlib inline

pd.set_option('display.max_columns',30)

# %%
df=pd.read_csv("Downloads/heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.shape
# Out:
# (299, 13)

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
cat_col=[col for col in df.columns if df[col].dtype == 'object']
num_col=[col for col in df.columns if df[col].dtype != 'object']

# %%
cat_col
# Out:
# []

# %%
num_col
# Out:
# ['age',
#  'anaemia',
#  'creatinine_phosphokinase',
#  'diabetes',
#  'ejection_fraction',
#  'high_blood_pressure',
#  'platelets',
#  'serum_creatinine',
#  'serum_sodium',
#  'sex',
#  'smoking',
#  'time',
#  'DEATH_EVENT']

# %%
df['age']
# Out:
# 0      75.0
# 1      55.0
# 2      65.0
# 3      50.0
# 4      65.0
#        ...
# 294    62.0
# 295    55.0
# 296    45.0
# 297    45.0
# 298    50.0
# Name: age, Length: 299, dtype: float64

# %%
#1.What is the distribution of age among heart failure patients in the dataset?
plt.figure(figsize=(10,6))
sns.histplot(df['age'].dropna(),kde=True,color="skyblue",edgecolor="pink")
plt.title('Distribution of Age among Heart Failure Patients')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
#2.How does the death rate vary with age?
mortality_rate = df.groupby('age')['DEATH_EVENT'].mean() * 100

# %%
mortality_rate
# Out:
# age
# 40.000      0.000000
# 41.000      0.000000
# 42.000     14.285714
# 43.000      0.000000
# 44.000      0.000000
# 45.000     31.578947
# 46.000     33.333333
# 47.000      0.000000
# 48.000    100.000000
# 49.000     25.000000
# 50.000     29.629630
# 51.000     25.000000
# 52.000      0.000000
# 53.000     10.000000
# 54.000     50.000000
# 55.000     17.647059
# 56.000      0.000000
# 57.000     50.000000
# 58.000     20.000000
# 59.000     75.000000
# 60.000     39.393939
# 60.667     50.000000
# 61.000      0.000000
# 62.000     20.000000
# 63.000      0.000000
# 64.000      0.000000
# 65.000     30.769231
# 66.000      0.000000
# 67.000      0.000000
# 68.000     40.000000
# 69.000     66.666667
# 70.000     28.000000
# 72.000     71.428571
# 73.000     25.000000
# 75.000     54.545455
# 77.000     50.000000
# 78.000      0.000000
# 79.000      0.000000
# 80.000     71.428571
# 81.000      0.000000
# 82.000    100.000000
# 85.000     50.000000
# 86.000    100.000000
# ...

# %%
plt.figure(figsize=(16,12))
sns.barplot(x=mortality_rate.index,y=mortality_rate.values,data=df,color="blue")
plt.title('How does the death rate vary with age?')
plt.xlabel('Morality rate')
plt.ylabel('Age')

plt.show()

# %%
#3.What is the percentage of male and female patients in the dataset?
df['sex'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
gender_count=df['sex'].value_counts(normalize =True)
print(gender_count)
gender_percentage=gender_count*100
print(gender_percentage)
# Out:
# sex
# 1    0.648829
# 0    0.351171
# Name: proportion, dtype: float64
# sex
# 1    64.882943
# 0    35.117057
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['sex'].value_counts(normalize=True)*100,data=df,color="Magenta")
plt.title("the percentage of male and female patients in the dataset")
plt.xlabel("sex percentage")
plt.ylabel("count")
plt.show()

# %%
#4.How does the platelet count vary among different age groups?
plt.figure(figsize=(10, 5))
sns.boxplot(x='age', y='platelets', data=df, color="yellow")
plt.title("Platelet Count Variation Among Different Age Groups")
plt.xlabel("Age")
plt.ylabel("Platelet Count")
plt.show()

# %%
df['age']=df['age'].astype(int,errors="ignore")
df['age']
# Out:
# 0      75
# 1      55
# 2      65
# 3      50
# 4      65
#        ..
# 294    62
# 295    55
# 296    45
# 297    45
# 298    50
# Name: age, Length: 299, dtype: int32

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x='age', y='platelets', data=df, color="yellow")
plt.title("Platelet Count Variation Among Different Age Groups")
plt.xlabel("Age")
plt.ylabel("Platelet Count")
plt.show()

# %%
df['serum_creatinine']
# Out:
# 0      1.9
# 1      1.1
# 2      1.3
# 3      1.9
# 4      2.7
#       ...
# 294    1.1
# 295    1.2
# 296    0.8
# 297    1.4
# 298    1.6
# Name: serum_creatinine, Length: 299, dtype: float64

# %%
#5.Is a correlation between creatinine and sodium levels in the blood?
df['serum_creatinine']=df['serum_creatinine'].astype(int,errors='ignore')
df['serum_creatinine']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      2
#       ..
# 294    1
# 295    1
# 296    0
# 297    1
# 298    1
# Name: serum_creatinine, Length: 299, dtype: int32

# %%
df['serum_sodium']
# Out:
# 0      130
# 1      136
# 2      129
# 3      137
# 4      116
#       ...
# 294    143
# 295    139
# 296    138
# 297    140
# 298    136
# Name: serum_sodium, Length: 299, dtype: int64

# %%
correlation = df['serum_creatinine'].corr(df['serumsodium']
print("Correlation coefficient between creatinine and sodium levels:", correlation)
# Out:
# Correlation coefficient between creatinine and sodium levels: -0.1614164358444905

# %% [raw]
# Interpretation:
#
# If the correlation coefficient is close to 1, it indicates a strong positive correlation, meaning as one variable increases, the other variable also tends to increase.
# If the correlation coefficient is close to -1, it indicates a strong negative correlation, meaning as one variable increases, the other variable tends to decrease.
# If the correlation coefficient is close to 0, it indicates a weak correlation, meaning there is little to no linear relationship between the two variables.

# %%
#6.how does the perevalence of high blood pressure differr between male and female patients?
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df['high_blood_pressure']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 294    1
# 295    0
# 296    0
# 297    0
# 298    0
# Name: high_blood_pressure, Length: 299, dtype: int64

# %%
df['sex'].value_counts(normalize=True)
# Out:
# sex
# 1    0.648829
# 0    0.351171
# Name: proportion, dtype: float64

# %%
#6.how does the perevalence of high blood pressure differr between male and female patients?
plt.figure(figsize=(10,7))
sns.boxplot(x=df['sex'],y=df['high_blood_pressure'], palette="Set2")
plt.title("the perevalence of high blood pressure differr between male and female patients")
plt.xlabel("gender")
plt.ylabel("high_blood_pressure")
plt.xticks([0,1],["female","male"])
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x=df['sex'],y=df['high_blood_pressure'], palette="Set2")
plt.title("the perevalence of high blood pressure differr between male and female patients")
plt.xlabel("gender")
plt.ylabel("high_blood_pressure")
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT', 'prevalence_male', 'prevalence_female'],
#       dtype='object')

# %%
df['DEATH_EVENT']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
#7.what is the relationship between the smoking_habits and occurance of heart_failure?
#heart_failure ==>DEATH_EVENT
plt.figure(figsize=(10,7))
sns.barplot(x=df['DEATH_EVENT'],y=df['smoking'],palette="tab10")
plt.title("relationship between the smoking_habits and occurance of heart_failure")
plt.ylabel("smoking")
plt.xlabel("DEATH_EVENT")
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.barplot(x=df['DEATH_EVENT'],y=df['smoking'],palette="tab10")
plt.title("relationship between the smoking_habits and occurance of heart_failure")
plt.ylabel("smoking")
plt.xlabel("DEATH_EVENT")
plt.xticks([1,0],["heart_failure","no_heart_failure"])
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.violinplot(x=df['smoking'],y=df['DEATH_EVENT'],palette="tab10")
plt.title("relationship between the smoking_habits and occurance of heart_failure")
plt.xlabel("smoking")
plt.ylabel("DEATH_EVENT")
plt.show()

# %%
#8.Are there any noticeable pattern in distribtion of death events across different age groups?
plt.figure(figsize=(10,5))
sns.boxplot(y=df['DEATH_EVENT'],x=df['age'], palette="Set2")
plt.title(" Pattern in distribtion of death events across different age groups")
plt.ylabel("DEATH_EVENT")
plt.xlabel("age")
plt.show()

# %%
plt.figure(figsize=(16,12))
df['age']=df['age'].astype(int,errors="ignore")
df['age']
sns.barplot(y=df['DEATH_EVENT'],x=df['age'], palette="Set2")
plt.title(" Pattern in distribtion of death events across different age groups")
plt.ylabel("DEATH_EVENT")
plt.xlabel("age")
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT', 'prevalence_male', 'prevalence_female'],
#       dtype='object')

# %%
#9.Is there any significant difference in ejection fraction on between patients with and without diabetes?
df['ejection_fraction'].unique()
# Out:
# array([20, 38, 40, 15, 60, 65, 35, 25, 30, 50, 14, 55, 45, 62, 80, 17, 70],
#       dtype=int64)

# %%
df['diabetes'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
plt.figure(figsize=(12,3))
sns.boxplot(x=df['ejection_fraction'],y=df['diabetes'],hue=df['DEATH_EVENT'])
plt.title("Ejection Fraction Distribution by Diabetes Status")
plt.ylabel("Diabetes")
plt.xlabel("Ejection Fraction")
plt.show()

# %%
plt.figure(figsize=(23,5))
sns.boxplot(x=df['diabetes'],y=df['ejection_fraction'],hue=df['DEATH_EVENT'])
plt.title("Ejection Fraction Distribution by Diabetes Status")
plt.xlabel("Diabetes")
plt.ylabel("Ejection Fraction")
plt.xticks([0, 1], ['No Diabetes', 'Diabetes'])
plt.show()

# %% [raw]
# #10.how does the serum_creatinine level vary between patients who survived and those who didnot?
# df['serum_creatinine'].unique()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='DEATH_EVENT', y='serum_creatinine', data=df)
plt.title("Serum Creatinine Level Variation Between Patients Who Survived and Those Who Did Not")
plt.xlabel("DEATH_EVENT")
plt.ylabel("Serum Creatinine Level")
plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x='DEATH_EVENT', y='serum_creatinine', data=df)
plt.title("Serum Creatinine Level Variation Between Patients Who Survived and Those Who Did Not")
plt.xlabel("DEATH_EVENT")
plt.ylabel("Serum Creatinine Level")
plt.xticks([0, 1], ['Survived', 'Did Not Survive'])
plt.show()
